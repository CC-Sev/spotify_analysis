# %% [markdown]
# # <font color=green>Spotify Exploratory Analysis</font>
#
# > <font color=lightgreen>**This is a practice on an exploratory analysis for Spotify Data Set**</font>
#
# _This is where the fun begins_.
#
# [Click here for repo](https://github.com/CC-Sev/spotify_analysis)
#
# ![green-divider]

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset-2.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                track_id                               artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5           5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6           6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7           7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8           8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9           9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df.shape
# Out:
# (114000, 21)

# %%
df['popularity'].isnull().any()
# Out:
# False

# %%
np.isfinite(df['popularity']).all()
# Out:
# True

# %%
df.isnull().all()
# Out:
# Unnamed: 0          False
# track_id            False
# artists             False
# album_name          False
# track_name          False
# popularity          False
# duration_ms         False
# explicit            False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# time_signature      False
# track_genre         False
# dtype: bool

# %%
df['artists'].isnull().value_counts()
# Out:
# artists
# False    113999
# True          1
# Name: count, dtype: int64

# %%
df[df['artists'].isnull()]
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %%
df['album_name'].isnull().value_counts()
# Out:
# album_name
# False    113999
# True          1
# Name: count, dtype: int64

# %%
nan_row = df[df['album_name'].isnull()]

# %%
df['track_name'].isnull().value_counts()
# Out:
# track_name
# False    113999
# True          1
# Name: count, dtype: int64

# %%
(df['popularity'] == 0).any()
# Out:
# True

# %%
(df[df['popularity']==0]).any()
# Out:
# Unnamed: 0           True
# track_id             True
# artists              True
# album_name           True
# track_name           True
# popularity          False
# duration_ms          True
# explicit             True
# danceability         True
# energy               True
# key                  True
# loudness             True
# mode                 True
# speechiness          True
# acousticness         True
# instrumentalness     True
# liveness             True
# valence              True
# tempo                True
# time_signature       True
# track_genre          True
# dtype: bool

# %%
nan_row
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %%
df['speechiness'].describe()
# Out:
# count    114000.000000
# mean          0.084652
# std           0.105732
# min           0.000000
# 25%           0.035900
# 50%           0.048900
# 75%           0.084500
# max           0.965000
# Name: speechiness, dtype: float64

# %%
df_copy = df

# %%
df_copy = df_copy.drop(df_copy[df_copy==0].index)

# %%
df_copy.shape
# Out:
# (0, 21)

# %%
df_copy
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Cannot drop any rows or columns with 0s as it will delete the entire dataframe. Many of the rows have an attribute with a value of zero.

# %%
df_copy = df

# %%
df_copy
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df[df == ' '].any()
# Out:
# Unnamed: 0          False
# track_id            False
# artists             False
# album_name          False
# track_name          False
# popularity          False
# duration_ms         False
# explicit            False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# time_signature      False
# track_genre         False
# dtype: bool

# %%
df.drop(65900,inplace = True)

# %%
df.shape
# Out:
# (113999, 21)

# %% [markdown]
# ## <font color=green>Conclusion of Exploring Data</font>
#
# <font color=lightgreen>After exploring the dataset, several key insights have been identified:
#
# - **Data Integrity**: The dataset appears to be well-structured with consistent data types and minimal missing values.
# - **Feature Distribution**: The distribution of features such as 'popularity', 'duration_ms', and 'tempo' indicates that they might follow a skewed distribution, which could be further investigated during modeling.
# - **Outliers**: Some features exhibit outliers, particularly in the 'popularity' and 'duration_ms' columns. These outliers may require further analysis to determine if they are genuine data points or errors.
# - **Correlation Analysis**: A preliminary correlation analysis reveals potential relationships between certain features, such as 'energy' and 'loudness', which could be explored in more detail.
#
# Overall, the initial exploration provides valuable insights into the dataset's characteristics and potential areas for further investigation. Further analysis, feature engineering, and modeling steps can be guided by these findings to derive meaningful insights and build accurate predictive models.</font>
